# %% [markdown]
# # Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
Message = input("Enter your message: ")
print(Message)
# Out:
# Enter your message: Hey Shiva Kumar
# Hey Shiva Kumar

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num = int(input("Enter Any Number: "))
if num == 0:
  print("The Entered value is Zero")
elif num > 0:
  print("The Entered value is Positive")
else:
  print("The entered value is Negative")
# Out:
# Enter Any Number: -1
# The entered value is Negative

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
x = int(input("Enter 1st number:"))
y = int(input("Enter 2nd number:"))
z = int(input("E1nter 3rd number:"))
if x >= y and x >= z:
    print("largest num is:",x)
elif y >= x and y >= z:
  print("largest num is:",y)
else:
  print("largest num is:",z)
# Out:
# Enter 1st number:10
# Enter 2nd number:12
# E1nter 3rd number:13
# largest num is: 13

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
num = int(input("Enter any Number: "))
fact = 1
for num in range(1,num+1):
  fact = fact*num
print(fact)
# Out:
# Enter any Number: 5
# 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
a = 10
b = 1.3
str1 = "Shiva Kumar"
c = True

print(f"Value of a is {a} and type is {type(a)}")
print(f"Value of b is {b} and type is {type(b)}")
print(f"Value of str1 is \"{str1} \" and type is {type(str1)}")
print(f"Value of c is {c} and type is {type(c)}")
# Out:
# Value of a is 10 and type is <class 'int'>
# Value of b is 1.3 and type is <class 'float'>
# Value of str1 is "Shiva Kumar " and type is <class 'str'>
# Value of c is True and type is <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
a = 10
b = 20
a = a+b
b = a-b
a = a-b
print(f"The value of a is: {a}")
print(f"The value of b is: {b}")
# Out:
# The value of a is: 20
# The value of b is: 10

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
celcius = int(input("Enter the value in Celcius degree : "))
print(f"The {celcius} degree in Fahrenheit is {(celcius * 1.8) + 32}")
# Out:
# Enter the value in Celcius degree : 12
# The 12 degree in Fahrenheit is 53.6

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
str1 = "Hello!"
str2 = "World!!"
print(str1 +" "+ str2)
# Out:
# Hello! World!!

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
x = 10
if type(x) == int :
    print(f"{x} is an Integer")
elif type(x) == float :
    print(f"{x} is a Float")
elif type(x) == str :
    print(f"{x} is a String")
elif type(x) == bool :
    print(f"{x} is a Boolean")
elif type(x) == complex:
    print(f"{x} is a Complex Number")
else:
    print(f"{x} is of Other types")
# Out:
# 10 is an Integer

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
a = int(input("Enter First Number: "))
b = int(input("Enter Second Number: "))
print("addition:",a+b)
print("substraction:",a-b)
print("multiplication:",a*b)
print("division:",a/b)
# Out:
# Enter First Number: 10
# Enter Second Number: 20
# addition: 30
# substraction: -10
# multiplication: 200
# division: 0.5

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
x = 10
y = 40
print("equal to:",x == y)
print("not equal to:",x != y)
print("greater than:",x > y)
print("less than:",x < y)
# Out:
# equal to: False
# not equal to: True
# greater than: False
# less than: True

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
a = True
b = False

print("a and b:", a and b)
print("a or b:", a or b)
print("not a:", not a)

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
num = int(input("Enter any number: "))
print(num ** 2)
# Out:
# Enter any number: 16
# 256

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
num = int(input("Enter any Number: "))
if num % 2 ==0:
  print("Even Number")
else:
  print("Odd Number")
# Out:
# Enter any Number: 13
# Odd Number

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
num = int(input("Enter any Number: "))
sum = 0
for i in range(0,num + 1):
  sum = sum + i
print(sum)
# Out:
# Enter any Number: 3
# 6

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(year, "is a Leap Year")
else:
    print(year, "is not a Leap Year")
# Out:
# Enter a year: 2023
# 2023 is not a Leap Year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
string = str(input("Enter any string: "))
reversed = ''
for char in string:
  reversed = char + reversed
print(reversed)
# Out:
# Enter any string: shiva
# avihs

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
string = str(input("Enter any string: "))
string = string.lower()
reversed = ''
for char in string:
  reversed = char + reversed
if(string == reversed):
  print("Palindrome")
else:
  print("Not Palindrome")
# Out:
# Enter any string: Madam
# Palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
ls = [1,13,4,16,7,8,10]
sorted = ls.sort()
print(ls)
# Out:
# [1, 4, 7, 8, 10, 13, 16]
